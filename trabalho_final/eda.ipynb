# %%
import pandas as pd

# %%
dsViaturas = pd.read_csv('viaturas.csv')
dsViaturas.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7563 entries, 0 to 7562
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   alteracoes    7563 non-null   object
#  1   com_problema  3349 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 118.3+ KB

# %%
dsViaturas.head(15)
# Out:
#                                            alteracoes  com_problema
# 0                                                  nc           0.0
# 1                               conforme pdi anterior           0.0
# 2    painel informando a necessidade de troca de oleo           1.0
# 3                                                  sa           0.0
# 4                             sem alteracoes visiveis           0.0
# 5                                                 s a           0.0
# 6                                                 nao           0.0
# 7   viatura com ruido ao acelerar nas retomadas a ...           1.0
# 8                      ar condicionado sem eficiencia           0.0
# 9              ar condicionado com problemas nao gela           0.0
# 10                      ar condicionado com problemas           0.0
# 11     vidro do farol de milha lado esquerdo quebrado           0.0
# 12                                     sem alteracoes           0.0
# ...

# %%
dsViaturas['com_problema'].value_counts()
# Out:
# 0.0    1773
# 1.0    1576
# Name: com_problema, dtype: int64

# %%
dsViaturas['alteracoes'].apply(len).max()
# Out:
# 2095

# %%
dsEscala = pd.read_csv('escala.csv', encoding = "ISO-8859-1")
dsEscala.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4281 entries, 0 to 4280
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   MATRICULA                   4281 non-null   int64
#  1   NOME_COMPLETO               4281 non-null   object
#  2   PRODUTIVIDADE_CORRENTE_PRF  4281 non-null   float64
#  3   NUM_PDI                     4281 non-null   int64
#  4   PRODUTIVIDADE_PDI           4281 non-null   int64
#  5   ID_UNIDADE_ORGANIZACIONAL   4281 non-null   int64
#  6   UF                          4281 non-null   object
#  7   UNIDADE_ORGANIZACIONAL      4281 non-null   object
#  8   DATA_HORA_INICIO            4281 non-null   object
#  9   DATA_HORA_FIM               4281 non-null   object
#  10  TIPO_PD                     4281 non-null   int64
#  11  TIPO_EMPENHO                4281 non-null   int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 401.5+ KB

# %%
dsEscala.head(10)
# Out:
#    MATRICULA                                      NOME_COMPLETO  \
# 0     162636                 GYTMLI8U MXZI8U G8UMY9 5Y XZYVY58U
# 1    9829909          1QZX3JCI9CU MILLIX3J CXZVXLUU 5Y ULIVYIZX
# 2    9838266                              PXML8U XLVYS 5X SILVX
# 3    9838266                              PXML8U XLVYS 5X SILVX
# 4    9876756                         XLTYMIZ8U 8ULINT8U CZI9T8U
# 5    9875656                           VI9LXN CXMP8U9 58U9 ZYI9
# 6    1118186                          58UMGLX9 1QZYIZY MXCUX58U
# 7     159783                  J8USMY YVXNGYLISTX 5Y JYSMS SILVX
# 8    1201828  9IM8UNXZ5Y MXN8UYL 58U 98UC8UZZ8U 5Y LIMX Y 9ILVX
# 9     502667                       NYLIS NYMT8UN 5X CMNUX SILVX
#
#    PRODUTIVIDADE_CORRENTE_PRF  NUM_PDI  PRODUTIVIDADE_PDI  \
# 0                         0.0  2192898                  1
# 1                         1.7  2280233                  6
# 2                         0.1  2286293                  2
# ...

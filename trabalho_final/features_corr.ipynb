# %%
#analisando a correlação de variáveis
import pandas as pd
df = pd.read_csv('features_corr.csv')
df.sample(10)
# Out:
# C:\Users\PRF\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#      Unnamed: 0  Unnamed: 0.1         0         1         2         3  \
# 945         944     -0.003139 -0.001013 -0.002597 -0.000631 -0.001270
# 3456       3455     -0.030943 -0.001013 -0.002597 -0.000631 -0.001270
# 185         184      0.031003  0.113699 -0.003489  0.449705 -0.001706
# 3496       3495      0.047543 -0.001352 -0.003465 -0.000841 -0.001695
# 4274       4273           NaN       NaN       NaN       NaN       NaN
# 3609       3608           NaN       NaN       NaN       NaN       NaN
# 3442       3441     -0.020881 -0.001970 -0.005048 -0.001225 -0.002469
# 4308       4307      0.001751  0.032505 -0.029939 -0.008913 -0.006440
# 2602       2601           NaN       NaN       NaN       NaN       NaN
# ...

# %%
df.shape
# Out:
# (4379, 4380)

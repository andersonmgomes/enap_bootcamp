# %%
import pandas as pd

ds = pd.read_csv('Advertising.csv')

ds.drop('Unnamed: 0', axis=1, inplace=True)

ds
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
from autoML import AutoML

automl = AutoML(ds, 'sales')
automl.setMinXYcorrRate(0.05)
automl.setNFeaturesThreshold(0.5)
automl.getResults().head(10)
# Out:
#                algorithm                features n_features  train_time  \
# 0  DecisionTreeRegressor             (TV, radio)          2    2.870939
# 1    KNeighborsRegressor             (TV, radio)          2    3.630881
# 2                    SVR             (TV, radio)          2    3.738964
# 3       LinearRegression  (TV, radio, newspaper)          3    5.496791
# 4    KNeighborsRegressor  (TV, radio, newspaper)          3    3.869867
# 5       LinearRegression             (TV, radio)          2    5.109560
# 6                    SVR  (TV, radio, newspaper)          3    3.709664
# 7                    SVR         (TV, newspaper)          2    3.738962
# 8       LinearRegression         (TV, newspaper)          2    3.641836
# 9    KNeighborsRegressor         (TV, newspaper)          2    3.753042
#
#       mem_max        r2  neg_mean_absolute_error  neg_mean_squared_error
# 0  208.804688  0.912104                -0.055315               -0.004528
# ...

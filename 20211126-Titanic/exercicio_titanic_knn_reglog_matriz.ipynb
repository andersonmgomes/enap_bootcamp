# %% [markdown]
# ---
# # Exercício Titanic - kNN, Regressão Logística
# ---
# **Machine Learning em Projetos (Erick Muzart e Fernando melo)**
# Tópicos:
# - One-hot Encoder get-dummies
# - Knn
# - Regressão logística
# - Matriz de confusão
#
# <br>
# ------------------------------------------------
#
# Usando dados do Titanic, descritos em: https://www.openml.org/d/40945

# %% [markdown]
# ## Carregar bibliotecas

# %%
# Importar bibliotecas pandas, plot_confusion_matrix, train_test_split, matplotlib, metrics
import pandas as pd

# %% [markdown]
# ## Análise exploratória dos dados

# %%
# Ler dados do Titanic a partir do site Openml.org
df = pd.read_csv('https://www.openml.org/data/get_csv/16826755/phpMYEkMl', na_values='?')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
nan_series = df.isna().sum()/len(df)
nan_series
# Out:
# pclass       0.000000
# survived     0.000000
# name         0.000000
# sex          0.000000
# age          0.200917
# sibsp        0.000000
# parch        0.000000
# ticket       0.000000
# fare         0.000764
# cabin        0.774637
# embarked     0.001528
# boat         0.628724
# body         0.907563
# home.dest    0.430863
# dtype: float64

# %%
highest_nans = nan_series[nan_series > 0.5].index
highest_nans
# Out:
# Index(['cabin', 'boat', 'body'], dtype='object')

# %%
#cabin feature
#apply: people with the same ticket stay in the same cabin
df_cabin_nan = df.loc[df.cabin.isna()]
df_cabin_nan
# Out:
#       pclass  survived                          name     sex   age  sibsp  \
# 9          1         0       Artagaveytia, Mr. Ramon    male  71.0      0
# 13         1         1  Barber, Miss. Ellen 'Nellie'  female  26.0      0
# 15         1         0           Baumann, Mr. John D    male   NaN      0
# 23         1         1         Bidois, Miss. Rosalie  female  42.0      0
# 25         1         0           Birnbaum, Mr. Jakob    male  25.0      0
# ...      ...       ...                           ...     ...   ...    ...
# 1304       3         0          Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0         Zabour, Miss. Thamine  female   NaN      1
# 1306       3         0     Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0           Zakarian, Mr. Ortin    male  27.0      0
# 1308       3         0            Zimmerman, Mr. Leo    male  29.0      0
#
#       parch    ticket      fare cabin embarked boat   body  \
# 9         0  PC 17609   49.5042   NaN        C  NaN   22.0
# 13        0     19877   78.8500   NaN        S    6    NaN
# 15        0  PC 17318   25.9250   NaN        S  NaN    NaN
# 23        0  PC 17757  227.5250   NaN        C    4    NaN
# 25        0     13905   26.0000   NaN        C  NaN  148.0
# ...     ...       ...       ...   ...      ...  ...    ...
# 1304      0      2665   14.4542   NaN        C  NaN  328.0
# 1305      0      2665   14.4542   NaN        C  NaN    NaN
# 1306      0      2656    7.2250   NaN        C  NaN  304.0
# 1307      0      2670    7.2250   NaN        C  NaN    NaN
# 1308      0    315082    7.8750   NaN        S  NaN    NaN
#
#                 home.dest
# 9     Montevideo, Uruguay
# 13                    NaN
# 15           New York, NY
# 23                    NaN
# 25      San Francisco, CA
# ...                   ...
# 1304                  NaN
# 1305                  NaN
# 1306                  NaN
# 1307                  NaN
# 1308                  NaN
#
# [1014 rows x 14 columns]

# %%
df.cabin.describe()
# Out:
# count             295
# unique            186
# top       C23 C25 C27
# freq                6
# Name: cabin, dtype: object

# %%
df_cabin_notnan = df.loc[df.cabin.isna()==False]
df_cabin_notnan
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1189       3         1                  Sandstrom, Miss. Marguerite Rut
# 1217       3         0       Soholt, Mr. Peter Andreas Lauritz Andersen
# 1230       3         0                       Strom, Miss. Telma Matilda
# 1231       3         0       Strom, Mrs. Wilhelm (Elna Matilda Persson)
# 1249       3         0                                 Tobin, Mr. Roger
#
#          sex      age  sibsp  parch   ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0    24160  211.3375       B5        S    2
# 1       male   0.9167      1      2   113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2   113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2   113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2   113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...      ...       ...      ...      ...  ...
# 1189  female   4.0000      1      1  PP 9549   16.7000       G6        S   13
# 1217    male  19.0000      0      0   348124    7.6500    F G73        S  NaN
# 1230  female   2.0000      0      1   347054   10.4625       G6        S  NaN
# 1231  female  29.0000      1      1   347054   10.4625       G6        S  NaN
# 1249    male      NaN      0      0   383121    7.7500      F38        Q  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1189    NaN                              NaN
# 1217    NaN                              NaN
# 1230    NaN                              NaN
# 1231    NaN                              NaN
# 1249    NaN                              NaN
#
# [295 rows x 14 columns]

# %%
df.sort_values('ticket').head(20)
# Out:
#      pclass  survived                                               name  \
# 67        1         1                               Cherry, Miss. Gladys
# 245       1         1  Rothes, the Countess. of (Lucy Noel Martha Dye...
# 195       1         1                              Maioni, Miss. Roberta
# 289       1         1                                Taussig, Miss. Ruth
# 291       1         1             Taussig, Mrs. Emil (Tillie Mandelbaum)
# 290       1         0                                  Taussig, Mr. Emil
# 232       1         0                     Porter, Mr. Walter Chamberlain
# 74        1         0                        Clifford, Mr. George Quincy
# 194       1         0                           Maguire, Mr. John Edward
# 34        1         0                           Borebank, Mr. John James
# 29        1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 303       1         0                           Warren, Mr. Frank Manley
# 304       1         1   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)
# 256       1         1                             Salomon, Mr. Abraham L
# 300       1         0                          Van der hoef, Mr. Wyckoff
# 128       1         0                                  Gee, Mr. Arthur H
# 159       1         1                       Hippach, Miss. Jean Gertrude
# 160       1         1    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)
# 22        1         1                              Behr, Mr. Karl Howell
# 164       1         1                    Homer, Mr. Harry ('Mr E Haven')
#
#         sex   age  sibsp  parch  ticket     fare cabin embarked boat   body  \
# 67   female  30.0      0      0  110152  86.5000   B77        S    8    NaN
# 245  female  33.0      0      0  110152  86.5000   B77        S    8    NaN
# 195  female  16.0      0      0  110152  86.5000   B79        S    8    NaN
# 289  female  18.0      0      2  110413  79.6500   E68        S    8    NaN
# 291  female  39.0      1      1  110413  79.6500   E67        S    8    NaN
# 290    male  52.0      1      1  110413  79.6500   E67        S  NaN    NaN
# 232    male  47.0      0      0  110465  52.0000  C110        S  NaN  207.0
# 74     male   NaN      0      0  110465  52.0000   A14        S  NaN    NaN
# 194    male  30.0      0      0  110469  26.0000  C106        S  NaN    NaN
# 34     male  42.0      0      0  110489  26.5500   D22        S  NaN    NaN
# 29     male  28.0      0      0  110564  26.5500   C52        S    D    NaN
# 303    male  64.0      1      0  110813  75.2500   D37        C  NaN    NaN
# 304  female  60.0      1      0  110813  75.2500   D37        C    5    NaN
# 256    male   NaN      0      0  111163  26.0000   NaN        S    1    NaN
# 300    male  61.0      0      0  111240  33.5000   B19        S  NaN  245.0
# 128    male  47.0      0      0  111320  38.5000   E63        S  NaN  275.0
# 159  female  16.0      0      1  111361  57.9792   B18        C    4    NaN
# 160  female  44.0      0      1  111361  57.9792   B18        C    4    NaN
# 22     male  26.0      0      0  111369  30.0000  C148        C    5    NaN
# 164    male  35.0      0      0  111426  26.5500   NaN        C   15    NaN
#
#                               home.dest
# 67                      London, England
# 245               London  Vancouver, BC
# 195                                 NaN
# 289                        New York, NY
# 291                        New York, NY
# 290                        New York, NY
# 232                       Worcester, MA
# 74                        Stoughton, MA
# 194                        Brockton, MA
# 34                London / Winnipeg, MB
# 29   Stockholm, Sweden / Washington, DC
# 303                        Portland, OR
# 304                        Portland, OR
# 256                        New York, NY
# 300                        Brooklyn, NY
# 128        St Anne's-on-Sea, Lancashire
# 159                         Chicago, IL
# 160                         Chicago, IL
# 22                         New York, NY
# 164                    Indianapolis, IN

# %%
from statistics import mode

for i, row in df_cabin_nan.iterrows():
    cabin = df[(df['cabin'].isna() == False) 
                & (df['ticket']==row.ticket) 
                & (df['ticket'].isna() == False)].cabin
    if len(cabin) > 0:
        cabin_list = list(cabin)
        print(df.iloc[i].cabin, ' - ', mode(cabin_list), ' - ', len(cabin))

# %%
df = df.drop(highest_nans, axis=1)
df

# %%
nan_series = df.isna().sum()/len(df)
nan_series[nan_series > 0]

# %%
df['home.dest'].unique()

# %%
df = df.drop('home.dest', axis=1)
df

# %%
nan_series = df.isna().sum()/len(df)
nan_series = nan_series[nan_series > 0]
nan_series

# %%
df.embarked.unique()

# %%
df.embarked.fillna(df.embarked.mode()[0], inplace=True)
df.embarked.value_counts()

# %%
nan_series = df.isna().sum()/len(df)
nan_series = nan_series[nan_series > 0]
nan_series

# %%
df[nan_series.index].describe()

# %%
df.age.fillna(df.age.mean(), inplace=True)
df.age.isna().sum()

# %%
df.fare.fillna(df.fare.mean(), inplace=True)
df.fare.isna().sum()

# %%
df.isna().sum()

# %%
df

# %%
df = df.drop(['name', 'ticket'], axis=1)
df

# %%
df.to_csv('titanic.csv')

# %%
from autoML import AutoML
automl = AutoML(df, y_colname='survived')
automl.getResults()

# %%
automl.getBestResult().features

# %%
# Mostrar as dimensões e as primerias linhas do dataset

# %%
# Mostra total de valores nulos por variável independente (features)

# %%
# Fazer um corte no dataset com as colunas:'age', 'pclass', 'sex', 'embarked', 'survived' e eliminar dados nulos.

# %%
# Mostrar novas dimensões do dataset após o corte

# %%
# Verifica balanceamento das classses (value_counts())

# %%
#mostra gráfico de barras do total de amostras por classe

# %% [markdown]
# ## Pré-processamento

# %%
# Atribuir valores para X e y

# Mostrar as dimensões de X e y

# %% [markdown]
# ### Encoding variáveis (features) categoricas :
# Se as variáveis não possuem uma ordem específica, geralmente a melhor opção é one hot-encoding (dummy encoding)

# %%
# Cria X com as features codificadas com ".get_dummies" do Pandas.

# Mostra o resultado da codificação one-hot encoding

# %%
# Dividir dados em treino e teste (70/30)

# %% [markdown]
# ## Treinamento dos modelos

# %% [markdown]
# ### Knn - K vizinhos mais próximos (K Nearest neighbors)

# %%
# Importar o modelo knn Classifier

# %%
# Instanciar modelo de regressão logística

# %%
# Treinar o modelo com os dados de treinamento

# %%
# Verificar a acurácia do modelo (.score)

# %%
# Verificar o f1_score do modelo, quando as classes estão desbalenceadas

# %% [markdown]
# ### Regressão Logística

# %%
# Instanciar modelo de regressão logística

# %%
# Treinar o modelo com os dados de treinamento

# %%
# Verificar a acurácia do modelo (.score)

# %%
# Verificar o f1_score do modelo, quando as classes estão desbalenceadas

# %% [markdown]
# ## Avaliação da qualidade do melhor modelo

# %%
# Importar a biblioteca (plot_confusion_matrix)

# %%
# Mostrar a Matriz de Confusão do melhor modelo treinado

# %% [markdown]
# ## Próximos passos
# - Fazer normalização dos dados (Standard Scalar)
# - Treinar outros modelos:
#   - Árvore de decisão (Decision Tree Classifier)
#   - Floresta aleatória (Random Forest Classifier)

# %%
# Árvore de decisão
clf = DecisionTreeClassifier(max_depth=4).fit(X_train, y_train)
clf.score(X_test, y_test)

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier

rf_class = RandomForestClassifier(n_estimators=120, max_depth=6, random_state=100).fit(X_train, y_train)
rf_class.score(X_test, y_test)
